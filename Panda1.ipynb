# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# Python Series

# %%
list1=["Numpy","pandas","matplotib","scikit_learn"]
s1=pd.Series(list1)
print(s1)
# Out:
# 0           Numpy
# 1          pandas
# 2       matplotib
# 3    scikit_learn
# dtype: object

# %%
s2=pd.Series(list1,index=["a","b","c","d"])
print(s2)
# Out:
# a           Numpy
# b          pandas
# c       matplotib
# d    scikit_learn
# dtype: object

# %% [markdown]
# Python DataFrame

# %%
data={"Name":["supun","kamal","nimal"],"place":["india","SL","os"]}
print(data)
# Out:
# {'Name': ['supun', 'kamal', 'nimal'], 'place': ['india', 'SL', 'os']}

# %% [markdown]
# Read a CSV File

# %%
data1=pd.read_csv("/vehicle.csv")

# %%
print(data1)
# Out:
#                                               Title  \
# 0                 Honda Vezel Limited 2017 for sale
# 1              Jaguar XF Fully Loaded 2013 for sale
# 2          Toyota CHR GT New Face 2wd 2020 for sale
# 3                   Toyota CHR Toyato 2017 for sale
# 4           Toyota Land Cruiser Prado 2015 for sale
# 5           Toyota Land Cruiser Prado 2007 for sale
# 6                           Honda CRV 2018 for sale
# 7                  Mitsubishi Xpander 2019 for sale
# 8                   Suzuki Alto Japan 2017 for sale
# 9                           MG ZS SUV 2018 for sale
# 10    Toyota Vitz FM Safety Edition 2 2017 for sale
# 11            Mitsubishi Montero 2014 2013 for sale
# 12           Suzuki Wagon R FX Safety 2016 for sale
# 13         Toyota CHR NGX 50 GT Turbo 2017 for sale
# 14                      Suzuki Maruti 2008 for sale
# 15                    Peugeot 405 GLD 1995 for sale
# 16        Toyota CHR GT BOOST IMPULSE 2018 for sale
# ...

# %%
df2=pd.DataFrame(data1)
df2.head()
# Out:
#                                       Title  \
# 0         Honda Vezel Limited 2017 for sale
# 1      Jaguar XF Fully Loaded 2013 for sale
# 2  Toyota CHR GT New Face 2wd 2020 for sale
# 3           Toyota CHR Toyato 2017 for sale
# 4   Toyota Land Cruiser Prado 2015 for sale
#
#                                            Sub_title          Price   Brand  \
# 0  Posted on 01 Sep 2:45 pm, Kurunegala City, Kur...  Rs 12,900,000   Honda
# 1  Posted on 28 Sep 10:23 am, Kurunegala City, Ku...  Rs 16,250,000  Jaguar
# 2       Posted on 16 Sep 1:16 pm, Colombo 7, Colombo  Rs 17,000,000  Toyota
# 3      Posted on 30 Sep 10:12 am, Colombo 7, Colombo  Rs 13,000,000  Toyota
# 4        Posted on 30 Sep 9:50 pm, Kelaniya, Gampaha  Rs 33,500,000  Toyota
#
#                 Model          Edition  Year Condition Transmission  \
# 0               Vezel          Limited  2017      Used    Automatic
# 1                  XF     Fully Loaded  2013      Used    Automatic
# ...

# %%
df2=pd.DataFrame(data1)
print(df2.head())
# Out:
#                                       Title  \
# 0         Honda Vezel Limited 2017 for sale
# 1      Jaguar XF Fully Loaded 2013 for sale
# 2  Toyota CHR GT New Face 2wd 2020 for sale
# 3           Toyota CHR Toyato 2017 for sale
# 4   Toyota Land Cruiser Prado 2015 for sale
#
#                                            Sub_title          Price   Brand  \
# 0  Posted on 01 Sep 2:45 pm, Kurunegala City, Kur...  Rs 12,900,000   Honda
# 1  Posted on 28 Sep 10:23 am, Kurunegala City, Ku...  Rs 16,250,000  Jaguar
# 2       Posted on 16 Sep 1:16 pm, Colombo 7, Colombo  Rs 17,000,000  Toyota
# 3      Posted on 30 Sep 10:12 am, Colombo 7, Colombo  Rs 13,000,000  Toyota
# 4        Posted on 30 Sep 9:50 pm, Kelaniya, Gampaha  Rs 33,500,000  Toyota
#
#                 Model          Edition  Year Condition Transmission  \
# 0               Vezel          Limited  2017      Used    Automatic
# 1                  XF     Fully Loaded  2013      Used    Automatic
# ...

# %%
print(df2.ndim)
print(df2.shape)
df2.info()
# Out:
# 2
# (28, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           28 non-null     object
#  1   Sub_title       28 non-null     object
#  2   Price           28 non-null     object
#  3   Brand           28 non-null     object
#  4   Model           28 non-null     object
#  5   Edition         20 non-null     object
#  6   Year            28 non-null     int64
#  7   Condition       28 non-null     object
#  8   Transmission    28 non-null     object
#  9   Body            24 non-null     object
#  10  Fuel            28 non-null     object
#  11  Capacity        28 non-null     object
#  12  Mileage         28 non-null     object
#  13  Location        28 non-null     object
#  14  Description     28 non-null     object
#  15  Post_URL        28 non-null     object
#  16  Seller_name     28 non-null     object
# ...
